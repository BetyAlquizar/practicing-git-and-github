# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
# To know which version of Python are we using do this:

import sys
print(sys.version)
# Out:
# 3.11.8 | packaged by conda-forge | (main, Feb 16 2024, 20:53:32) [GCC 12.3.0]

# %%
# This is a prictice in wrting comments using #

print("My name is Beatriz") # this is the command to write something
# Out:
# My name is Beatriz

# %%
## Errors in Python ##

# Print string as error message

frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 ## Errors in Python ##
#       2
#       3 # Print string as error message
# ----> 5 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %%
# Try to see built-in error message

print("Hello, Python!)
# Out:
#   Cell In[5], line 3
#     print("Hello, Python!)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
z=2+15
print(z)
# Out:
# 17

# %% [markdown]
# ## Types in Python ##

# %%
type("Hello, wrold!")
# Out:
# str

# %%
type(12)
# Out:
# int

# %%
type(12.34)
# Out:
# float

# %%
type(2)
# Out:
# int

# %%
float(2) # this is to convert from integer to float
# Out:
# 2.0

# %%
type(float(2))
# Out:
# float

# %%
type(1.1)
# Out:
# float

# %%
int(1.1)
# Out:
# 1

# %%
type(int(1.1))
# Out:
# int

# %%
int('1 y 2 son numeros naturales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('1 y 2 son numeros naturales')
#
# ValueError: invalid literal for int() with base 10: '1 y 2 son numeros naturales'

# %% [markdown]
# ## Boolean Data Type ##

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %%
type(True)
# Out:
# bool

# %%
print(7/2)
# Out:
# 3.5

# %%
print(7//2)
# Out:
# 3

# %%
type(7/2)
# Out:
# float

# %%
type(7//2)
# Out:
# int
